# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

# %%
products = []
prices = []
ratings = []
#ram = []
rom = []
display = []
rear_camera = []
front_camera = []
#battery = []

# %%
import numpy as np

for i in range(1,19):
    URL = "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&p%5B%5D=facets.brand%255B%255D%3DAPPLE&page="+str(i)
    uClient = uReq(URL)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html , "html.parser")
    for data in page_soup.findAll("div", {"class":"_3pLy-c row"}):
        names = data.find('div', attrs = {"class":"_4rR01T"})
        price = data.find('div', attrs = {"class":"_30jeq3 _1_WHN1"})
        rating = data.find('div', attrs = {"class":"_3LWZlK"})
        specification = data.find('div', attrs = {"class":"fMghEO"})

        for each in specification:
            col = each.find_all('li', attrs = {"class":"rgWa7D"})
            rom_ = col[0].text.split(' ')[0]
            #ram_ = ram_rom[0].split(' ')[0]
            #rom_ = ram_rom[1].split(' ')[]
            display_ = col[1].text.split(' ')[0]
            camera = col[2].text.split('|')
            try:
                front_camera.append(camera[1].replace('Front Camera',''))
            except:
                front_camera.append(np.nan)
            #battery_ = col[3].text.split(' ')[0]
            
        products.append(names.text)
        if price == None:
            prices.append(np.nan)
        else:
            prices.append(int(price.text.lstrip('₹').replace(',','')))
        if rating == None:
            ratings.append(np.nan)
        else:
            ratings.append(float(rating.text))
        #ram.append(ram_)
        rom.append(int(rom_))
        if display == None:
            display.append(np.camera)
        else:
            display.append(float(display_))
        rear_camera.append(camera[0].replace('Rear Camera',''))
        #battery.append(battery_)

# %%
#print(len(ram))
print(len(rom))
print(len(display))
print(len(rear_camera))
print(len(front_camera))
#print(len(battery))
print(len(ratings))
# Out:
# 428
# 428
# 428
# 428
# 428

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Product_Name': products, 'ROM': rom, 'Rear_Camera': rear_camera, 'Front_Camera': front_camera, 'Display': display, 'Ratings': ratings, 'Price': prices})

# %%
df
# Out:
#                                           Product_Name  ROM   Rear_Camera  \
# 0                  APPLE iPhone 14 (Starlight, 128 GB)  128  12MP + 12MP
# 1                       APPLE iPhone 14 (Blue, 128 GB)  128  12MP + 12MP
# 2                     APPLE iPhone 14 (Purple, 128 GB)  128  12MP + 12MP
# 3              APPLE iPhone 14 Plus (Midnight, 128 GB)  128  12MP + 12MP
# 4                APPLE iPhone 14 Plus (Purple, 128 GB)  128  12MP + 12MP
# ..                                                 ...  ...           ...
# 423                   APPLE iPhone XR (Yellow, 128 GB)  128        12MP
# 424                    APPLE iPhone X (Silver, 256 GB)  256  12MP + 12MP
# 425               APPLE iPhone XS (Space Grey, 256 GB)  256  12MP + 12MP
# 426  Apple iPhone XR (White, 128 GB) (Includes EarP...  128        12MP
# 427                    APPLE iPhone XR (White, 128 GB)  128        12MP
#
#     Front_Camera  Display  Ratings   Price
# 0          12MP     15.49      4.7   65999
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_Name  428 non-null    object
#  1   ROM           428 non-null    int64
#  2   Rear_Camera   428 non-null    object
#  3   Front_Camera  428 non-null    object
#  4   Display       428 non-null    float64
#  5   Ratings       428 non-null    float64
#  6   Price         428 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 23.5+ KB

# %%
df.isna().sum()
# Out:
# Product_Name    0
# ROM             0
# Rear_Camera     0
# Front_Camera    0
# Display         0
# Ratings         0
# Price           0
# dtype: int64
